# %%
import pandas as pd

# change the filename to your main events file
df = pd.read_csv("data_raw/data_final.csv")

print(df.shape)
print(df.columns)
df.head()
# Out:
# (166205, 54)
# Index(['session_id', 'session_position', 'session_length', 'track_id',
#        'skip_1', 'skip_2', 'skip_3', 'not_skipped', 'context_switch',
#        'no_pause_before_play', 'short_pause_before_play',
#        'long_pause_before_play', 'hist_user_behavior_n_seekfwd',
#        'hist_user_behavior_n_seekback', 'hist_user_behavior_is_shuffle',
#        'hour_of_day', 'date', 'premium', 'context_type',
#        'hist_user_behavior_reason_start', 'hist_user_behavior_reason_end',
#        'session_day', 'session_month', 'duration', 'release_year',
#        'us_popularity_estimate', 'acousticness', 'beat_strength', 'bounciness',
#        'danceability', 'dyn_range_mean', 'energy', 'flatness',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mechanism', 'mode',
#        'organism', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2',
# ...

# %%
import os
os.getcwd()
# Out:
# 'D:\\Yash Thakkar\\Projects\\music-analytics-jiosaavn'

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['ts'] = df['date'] + pd.to_timedelta(df['hour_of_day'], unit='h')

# %%
import pandas as pd

# change the filename to your main events file
df = pd.read_csv("../data_raw/data_final.csv")
df['skipped'] = ~df['not_skipped'].astype(bool)
