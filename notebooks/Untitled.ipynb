# %%
# Run this as one cell in the notebook (from your project root)
import os, sys
from importlib.util import find_spec

print("Working dir:", os.getcwd())
print("Files in project root (sample):", os.listdir(".")[:30])

csv_path = "data_raw/data_final.csv"
print("\nCSV exists at data_raw/data_final.csv ?", os.path.exists(csv_path))

# Check packages
for pkg in ("pandas","sqlalchemy","psycopg2"):
    print(f"{pkg}: ", "FOUND" if find_spec(pkg) else "MISSING")

# Quick DB connection test (adjust credentials if you changed them)
from sqlalchemy import create_engine, text
DB_USER = "postgres"          # change if using music_user
DB_PASS = "Tom&Jerry2704"     # change to your DB password
DB_HOST = "localhost"
DB_PORT = 5432
DB_NAME = "music_analytics"

url = f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
print("\nUsing DB URL:", url.replace(DB_PASS, "*****"))

try:
    engine = create_engine(url)
    with engine.connect() as conn:
        r = conn.execute(text("SELECT 1"))
        print("DB test OK:", r.scalar())
except Exception as e:
    import traceback
    traceback.print_exc()
    print("DB connection failed. Exception above.")
# Out:
# Working dir: D:\Yash Thakkar\Projects\music-analytics-jiosaavn
# Files in project root (sample): ['.ipynb_checkpoints', '.venv', 'dashboards', 'data_processed', 'data_raw', 'docs', 'notebooks', 'requirements.txt', 'sql', 'src', 'Untitled.ipynb']
#
# CSV exists at data_raw/data_final.csv ? True
# pandas:  FOUND
# sqlalchemy:  FOUND
# psycopg2:  FOUND
#
# Using DB URL: postgresql+psycopg2://postgres:*****@localhost:5432/music_analytics
# DB test OK: 1

# %%
# run in the same environment where you ran the ETL
# If the variable songs_df is not in scope, run the part of script that builds songs_df,
# or re-create it quickly by reading a small sample:

import pandas as pd
# quick load a small sample to inspect (adjust filename if different)
sample = pd.read_csv("data_raw/data_final.csv", nrows=10000, low_memory=False)

# Option A: if you already have songs_df variable in memory (from script),
# print its info, otherwise create songs_df from sample as shown below:
try:
    print("songs_df present? columns and shape:")
    print(songs_df.shape)
    print(songs_df.columns.tolist()[:80])   # first 80 column names
    display(songs_df.head(3))
except NameError:
    print("songs_df not in memory — building a clean songs_df from sample for inspection...")
    songs_cols = ['track_id','release_year','duration','track_duration_mins',
                  'acousticness','danceability','energy','instrumentalness',
                  'liveness','loudness','tempo','valence']
    # pick only columns that actually exist in the CSV
    available = [c for c in songs_cols if c in sample.columns]
    songs_df2 = sample[available].drop_duplicates(subset=['track_id']).rename(columns={'track_id':'song_id','duration':'duration_ms'})
    print("songs_df2 shape:", songs_df2.shape)
    print("songs_df2 columns:", songs_df2.columns.tolist())
    display(songs_df2.head(5))
# Out:
# songs_df present? columns and shape:
# songs_df not in memory — building a clean songs_df from sample for inspection...
# songs_df2 shape: (197, 12)
# songs_df2 columns: ['song_id', 'release_year', 'duration_ms', 'track_duration_mins', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'tempo', 'valence']
#                                     song_id  release_year  duration_ms  \
# 0    t_0479f24c-27d2-46d6-a00c-7ec928f2b539          2018   180.066666
# 45   t_9099cd7b-c238-47b7-9381-f23f2c1d1043          2018   236.796371
# 50   t_fc5df5ba-5396-49a7-8b29-35d0d28249e0          2018   231.266663
# 327  t_23cff8d6-d874-4b20-83dc-94e450e8aa20          2018   169.826675
# 353  t_64f3743c-f624-46bb-a579-0f3f9a07a123          2018   210.545258
#
#      track_duration_mins  acousticness  danceability    energy  \
# 0               3.001111      0.015848      0.653119  0.553465
# 45              3.946606      0.061811      0.877393  0.726828
# ...

# %%
import pandas as pd

df = pd.read_csv("data_raw/data_final.csv", nrows=5)
print(df.columns.tolist())
# Out:
# ['session_id', 'session_position', 'session_length', 'track_id', 'skip_1', 'skip_2', 'skip_3', 'not_skipped', 'context_switch', 'no_pause_before_play', 'short_pause_before_play', 'long_pause_before_play', 'hist_user_behavior_n_seekfwd', 'hist_user_behavior_n_seekback', 'hist_user_behavior_is_shuffle', 'hour_of_day', 'date', 'premium', 'context_type', 'hist_user_behavior_reason_start', 'hist_user_behavior_reason_end', 'session_day', 'session_month', 'duration', 'release_year', 'us_popularity_estimate', 'acousticness', 'beat_strength', 'bounciness', 'danceability', 'dyn_range_mean', 'energy', 'flatness', 'instrumentalness', 'key', 'liveness', 'loudness', 'mechanism', 'mode', 'organism', 'speechiness', 'tempo', 'time_signature', 'valence', 'acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3', 'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6', 'acoustic_vector_7', 'track_duration_mins', 'released_decade']
